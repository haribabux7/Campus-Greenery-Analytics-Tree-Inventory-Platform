# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data = pd.read_csv(r"C:\Users\lab\Documents\A BLOCK.csv")
labels = data['TREES NAME'].values
values = data['NUMBER OF TREES'].values
num_vars = len(labels)
angles = np.linspace(0, 2 * np.pi, num_vars, endpoint=False).tolist()
values = np.concatenate((values, [values[0]]))
angles += angles[:1]
fig, ax = plt.subplots(figsize=(6, 6), subplot_kw=dict(polar=True))
ax.fill(angles, values, color='blue', alpha=0.25)
ax.plot(angles, values, color='blue', linewidth=2)
ax.set_xticks(angles[:-1])
ax.set_xticklabels(labels)
plt.title("Radar Chart A BLOCK")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv(r"C:\Users\lab\Documents\B BLOCK.csv")
tree_names = data['TREES NAME']
number_of_trees = data['NUMBER OF TREES']
plt.figure(figsize=(10, 5))
plt.bar(tree_names, number_of_trees, color='blue')
plt.xlabel('Tree Name')
plt.ylabel('Number of Trees')
plt.title('B BLOCK')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv(r"C:\Users\lab\Documents\C BLOCK.csv")
x = data['TREES NAME']
y = data['NUMBER OF TREES']
plt.figure(figsize=(25,9))
plt.fill_between(x, y, color="skyblue", alpha=0.5)
plt.plot(x, y, color="Slateblue", alpha=0.6)
plt.xlabel('TREES NAME')
plt.ylabel('NUMBER OF TREES') 
plt.title('C BLOCK')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv(r"C:\Users\lab\Documents\D BLOCK.csv")
categories = data['TREES NAME']
values = data['NUMBER OF TREES']
fig, ax = plt.subplots()
ax.pie(values, labels=categories, wedgeprops={'width': 0.3}, startangle=90)
center_circle = plt.Circle((0,0), 0.70, fc='white')
fig.gca().add_artist(center_circle)
ax.axis('equal')
plt.title('D BLOCK')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
data2 = pd.read_csv(r"C:\Users\lab\Documents\E BLOCK.csv")
labels = data2['TREES NAME']
sizes = data2['NUMBER OF TREES']   
plt.figure(figsize=(10, 5))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, colors=plt.cm.Paired.colors)
plt.axis('equal')
plt.title('Pie Chart E')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv(r"C:\Users\lab\Documents\PARKING.csv")
heatmap_data = df.set_index('TREES NAME')['NUMBER OF TREES'].to_frame()
plt.figure(figsize=(10, 4))
sns.heatmap(heatmap_data.T, annot=True, cmap="coolwarm", cbar=True)
plt.title('PARKING')
plt.ylabel('')
plt.xlabel('TREES NAME')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv(r"C:\Users\lab\Documents\ST MICHAELS.csv")
tree_names = data['TREES NAME']
num_trees = data['NUMBER OF TREES']
plt.figure(figsize=(10, 6))
plt.barh(tree_names, num_trees, color='blue')
plt.xlabel('Number of Trees')
plt.ylabel('Tree Names')
plt.title('BAR ')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv(r"C:\Users\ELCOT\Documents\ST PATRICK'S.csv")
plt.figure(figsize=(10,6))
plt.plot(data['TREES NAME'], data['NUMBER OF TREES'], marker='o', color='b')
plt.title('ST PATRICKS', fontsize=14)
plt.xlabel('Tree Type', fontsize=12)
plt.ylabel('Number of Trees', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv(r"C:\Users\lab\Documents\ICSE.csv")
x = data['TREES NAME']
y = data['NUMBER OF TREES']
plt.figure(figsize=(13,5))
plt.scatter(x, y, c='blue', alpha=1)
plt.xlabel('TREES NAME')
plt.ylabel('NUMBER OF TREES')
plt.title('ICSE')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv(r"C:\Users\lab\Documents\GROUND.csv")
tree_names = data['TREES NAME']
num_trees = data['NUMBER OF TREE']
plt.figure(figsize=(10, 5))
plt.barh(tree_names, num_trees, color='blue')
plt.xlabel('Number of Trees')
plt.ylabel('Tree Names')
plt.title('GROUND')
plt.show()

# %%
import matplotlib.pyplot as plt
data = pd.read_csv(r"C:\Users\lab\Documents\ourcampus.csv")
plt.figure(figsize=(16,7))
plt.plot(data['TREES NAME'], data['NUMBER OF TREE'], marker='o', color='blue')
plt.title('OUR CAMPUS', fontsize=14)
plt.xlabel('TREES NAME', fontsize=12)
plt.ylabel('NUMBER OF TREE', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
